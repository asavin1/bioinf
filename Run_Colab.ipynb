# %% [markdown]
# <a href="https://colab.research.google.com/github/asavin1/bioinf/blob/main/Run_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> DeepLigType: Predicting Ligand Types of Protein-Ligand Binding Sites Using a Deep Learning Model </center>

# %% [markdown]
# #### * Resolving Fpocket Installation Issues with the Latest Colab Update (December 2023)
#
# The Colab runtime has been upgraded to CUDA 12.2 in December 2023. You can find the official Colab announcement here: [Link](https://github.com/googlecolab/colabtools/issues/4214#issue-2037844472)
#
# Currently, there is an issue with the installation process using Conda in Google Colab.
#
# Since Fpocket is also installed with conda, Fpocket cannot be used in the Google Colab version at the moment.
#
# Solution: Use the fallback runtime version of Google Colab.
#
# Tools-> Command Palette -> Use Fallback Runtime Version

# %% [markdown]
# ## * Install Libraries

# %%
# May need to be run twice. This is for fpocket installation
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
import torch

# Check if a GPU is available
if torch.cuda.is_available():
    # Get the name of the GPU
    gpu_name = torch.cuda.get_device_name(0)
    print(f"GPU: {gpu_name}")
else:
    print("No GPU available - You can't run the program")
# Out:
# GPU: Tesla T4

# %%
# !git clone https://github.com/drorhunvural/DeepLigType.git
# Out:
# Cloning into 'DeepLigType'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 413 (delta 68), reused 68 (delta 29), pack-reused 291 (from 1)
# Receiving objects: 100% (413/413), 74.68 MiB | 16.81 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
#To clone the project into your drive, please execute this cell.

# from google.colab import drive
# drive.mount('/content/drive')

# !git clone https://github.com/drorhunvural/DeepLigType.git '/content/drive/My Drive/your-target-directory'

# %%
#it takes 5-6 mins.
# !pip3 install torch torchvision torchaudio
# !pip install molgrid
# !pip install biopython
# !pip install scikit-learn
# !mamba install fpocket
# Out:
# Collecting torch
#   Downloading torch-2.10.0-3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting cuda-bindings==12.9.4 (from torch)
#   Downloading cuda_bindings-12.9.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.4.5 (from torch)
#   Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.6.0 (from torch)
#   Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings==12.9.4->torch)
#   Downloading cuda_pathfinder-1.4.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy (from torchvision)
#   Downloading numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.10.0-3-cp311-cp311-manylinux_2_28_x86_64.whl (915.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.5/915.5 MB 40.7 MB/s eta 0:00:00
# Downloading cuda_bindings-12.9.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 188.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 52.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 200.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 85.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 75.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 47.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 81.4 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 96.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 83.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 80.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 74.9 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 79.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 71.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 93.8 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 MB 83.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 MB 80.5 MB/s eta 0:00:00
# Downloading torchvision-0.25.0-cp311-cp311-manylinux_2_28_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 150.8 MB/s eta 0:00:00
# Downloading torchaudio-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 132.0 MB/s eta 0:00:00
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 87.8 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 156.1 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 157.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 152.3 MB/s eta 0:00:00
# Downloading cuda_pathfinder-1.4.3-py3-none-any.whl (47 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 27.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, cuda-pathfinder, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, cuda-bindings, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-3.0.3 cuda-bindings-12.9.4 cuda-pathfinder-1.4.3 filelock-3.25.2 fsspec-2026.2.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.3 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.4.5 nvidia-nvtx-cu12-12.8.90 pillow-12.1.1 sympy-1.14.0 torch-2.10.0 torchaudio-2.10.0 torchvision-0.25.0 triton-3.6.0 typing-extensions-4.15.0
# Collecting molgrid
#   Downloading molgrid-0.5.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/site-packages (from molgrid) (2.4.3)
# Collecting pytest (from molgrid)
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting pyquaternion (from molgrid)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Collecting iniconfig>=1.0.1 (from pytest->molgrid)
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.11/site-packages (from pytest->molgrid) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/site-packages (from pytest->molgrid) (1.5.0)
# Collecting pygments>=2.7.2 (from pytest->molgrid)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Downloading molgrid-0.5.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 7.9 MB/s eta 0:00:00
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 102.0 MB/s eta 0:00:00
# Installing collected packages: pyquaternion, pygments, iniconfig, pytest, molgrid
# Successfully installed iniconfig-2.3.0 molgrid-0.5.5 pygments-2.19.2 pyquaternion-0.9.9 pytest-9.0.2
# Collecting biopython
#   Downloading biopython-1.86-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from biopython) (2.4.3)
# Downloading biopython-1.86-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 86.3 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.86
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.11/site-packages (from scikit-learn) (2.4.3)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 139.0 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 97.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
#
# Looking for: ['fpocket']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  11%
# conda-forge/noarch    16%[+] 0.3s
# conda-forge/linux-64  20%
# conda-forge/noarch    33%[+] 0.4s
# conda-forge/linux-64  29%
# conda-forge/noarch    51%[+] 0.5s
# conda-forge/linux-64  34%
# conda-forge/noarch    63%[+] 0.6s
# conda-forge/linux-64  38%
# conda-forge/noarch    71%[+] 0.7s
# conda-forge/linux-64  38%
# conda-forge/noarch    71%[+] 0.8s
# conda-forge/linux-64  39%
# conda-forge/noarch    72%[+] 0.9s
# conda-forge/linux-64  43%
# conda-forge/noarch    81%[+] 1.0s
# conda-forge/linux-64  45%
# conda-forge/noarch    85%[+] 1.1s
# conda-forge/linux-64  49%
# conda-forge/noarch    94%[+] 1.2s
# conda-forge/linux-64  49%
# conda-forge/noarch    94%[+] 1.3s
# conda-forge/linux-64  49%
# conda-forge/noarch    94%conda-forge/noarch
# [+] 1.4s
# conda-forge/linux-64  53%[+] 1.5s
# conda-forge/linux-64  62%[+] 1.6s
# conda-forge/linux-64  65%[+] 1.7s
# conda-forge/linux-64  81%[+] 1.8s
# conda-forge/linux-64  95%[+] 1.9s
# conda-forge/linux-64  99%[+] 2.0s
# conda-forge/linux-64  99%[+] 2.1s
# conda-forge/linux-64  99%[+] 2.2s
# conda-forge/linux-64  99%[+] 2.3s
# conda-forge/linux-64  99%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - fpocket
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build               Channel           Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + zlib                  1.3.1  hb9d3cd8_2          conda-forge       92kB
#   + snappy                1.2.2  h03e3b7b_1          conda-forge       46kB
#   + libaec                1.1.5  h088129d_0          conda-forge       37kB
#   + libgfortran5         14.2.0  hf1ad2bd_2          conda-forge        1MB
#   + libjpeg-turbo         3.1.2  hb03c661_0          conda-forge      634kB
#   + blosc                1.21.6  he440d0b_1          conda-forge       48kB
#   + libgfortran          14.2.0  h69a702a_2          conda-forge       54kB
#   + hdf4                 4.2.15  h2a13503_7          conda-forge      757kB
#   + libzip               1.11.2  h6991a6a_0          conda-forge      109kB
#   + hdf5                 1.14.4  nompi_h2d575fe_105  conda-forge        4MB
#   + libnetcdf             4.9.2  nompi_h5ddbaa4_116  conda-forge      833kB
#   + fpocket               4.2.2  h7b35b64_0          conda-forge        2MB
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2024.12.14  hbcca054_0          conda-forge     Cached
#   + ca-certificates   2026.2.25  hbd8a1cb_0          conda-forge      147kB
#   - certifi          2024.12.14  pyhd8ed1ab_0        conda-forge     Cached
#   + certifi           2026.2.25  pyhd8ed1ab_0        conda-forge      151kB
#   - openssl               3.4.0  h7b32b05_1          conda-forge     Cached
#   + openssl               3.6.1  h35e630c_1          conda-forge        3MB
#
#   Summary:
#
#   Install: 12 packages
#   Upgrade: 3 packages
#
#   Total download: 13MB
#
# ─────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%ca-certificates                                    147.4kB @   2.3MB/s  0.1s
# certifi                                            151.4kB @   2.0MB/s  0.1s
# libaec                                              36.5kB @ 398.4kB/s  0.1s
# snappy                                              45.8kB @ 496.8kB/s  0.1s
# zlib                                                92.3kB @ 982.0kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   4%
# Extracting   (5)  ⣾  libgfortran5                                         1.5MB @  13.2MB/s  0.1s
# blosc                                               48.4kB @ 426.3kB/s  0.0s
# libgfortran                                         53.7kB @ 339.1kB/s  0.1s
# libzip                                             109.0kB @ 668.3kB/s  0.1s
# libjpeg-turbo                                      633.7kB @   3.8MB/s  0.1s
# hdf5                                                 4.0MB @  23.2MB/s  0.1s
# fpocket                                              1.8MB @  10.2MB/s  0.1s
# [+] 0.2s
# Downloading  (3)  65%
# Extracting  (10)  ⣾  hdf4                                               756.7kB @   3.4MB/s  0.1s
# libnetcdf                                          832.8kB @   3.7MB/s  0.1s
# openssl                                              3.2MB @  13.3MB/s  0.1s
# [+] 0.3s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 0.4s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 0.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 0.6s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
# !pip install numpy==1.26.4 #Otherwise molgrid library is giving an error
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 91.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.3
#     Uninstalling numpy-2.4.3:
#       Successfully uninstalled numpy-2.4.3
# Successfully installed numpy-1.26.4

# %% [markdown]
# ## * Predict.py

# %%
#Note: The input PDB file must be included within the DeepLigType project !! e.g. .../DeepLigType/5kw2.pdb

# %%
# Восстанавливаем оригинальный файл
# !cd /content/DeepLigType && git checkout predict.py

# Делаем одно простое исправление - заменяем torch.load
# !sed -i 's/torch\.load(trainedpth_dir)/torch.load(trainedpth_dir, weights_only=False)/g' /content/DeepLigType/predict.py

print("✅ Готово! Запускайте предсказание.")
# Out:
# Updated 1 path from the index
# ✅ Готово! Запускайте предсказание.

# %%
# Example: !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5xpp.pdb' -t "CNN_2023-08-30_acc_0.717969_59.26.pth"
# Example: !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5xpp.pdb' -t "CBAM_2023-08-29_acc_0.915781_74.16.pth"
# Example: !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5xpp.pdb' -t "DenseNet_2023-08-20_acc_0.930625_70.73.pth"
# Example: !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5xpp.pdb' -t "SeResNet_2023-08-30_val_acc_0.881406_68.16.pth"
# Example: !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5xpp.pdb' -t "ResNet18_2023-10-06_train_acc_0.883281.pth"

# !python '/content/DeepLigType/predict.py' -p '/content/DeepLigType/5XPP.pdb' -t "CBAM_2023-08-29_acc_0.915781_74.16.pth"

# %% [markdown]
# ## * Evaluation.py

# %%
#Note 1: Before running evaluation.py, please make sure you've downloaded 'pdb.molcache' (1.61 GB) and placed it in the 'dataset' folder within the project.
# You can find the download link in the provided README on GitHub.

# %%
#Note 2: If you wish to evaluate using other models such as CNN, SeResnet, etc., download from the link provided in the GitHub README.

# %%
# Example: !python '/content/DeepLigType/evaluation.py' -t "CNN_2023-08-30_acc_0.717969_59.26.pth"
# Example: !python '/content/DeepLigType/evaluation.py' -t "CBAM_2023-08-29_acc_0.915781_74.16.pth"
# Example: !python '/content/DeepLigType/evaluation.py' -t "DenseNet_2023-08-20_acc_0.930625_70.73.pth"
# Example: !python '/content/DeepLigType/evaluation.py' -t "SeResNet_2023-08-30_val_acc_0.881406_68.16.pth"
# Example: !python '/content/DeepLigType/evaluation.py' -t "ResNet18_2023-10-06_train_acc_0.883281.pth"

# !python '/content/DeepLigType/evaluation.py' -t "trainedmodels"

# %% [markdown]
# ## * Training.py

# %%
# Example: !python '/content/DeepLigType/train.py' -m "cbam"
# Example: !python '/content/DeepLigType/train.py' -m "seresnet"
# Example: !python '/content/DeepLigType/train.py' -m "resnet18"
# Example: !python '/content/DeepLigType/train.py' -m "cnn"
# Example: !python '/content/DeepLigType/train.py' -m "densenet"

# !python '/content/DeepLigType/train.py' -m "cnn"
# Out:
# Traceback (most recent call last):
#   File "/content/DeepLigType/train.py", line 66, in <module>
#     e_train = molgrid.ExampleProvider(stratify_min = 0, stratify_max = 5, stratify_step=1,  shuffle=False, recmolcache = molcache_path,stratify_receptor=False, balanced = False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: Could not open file: /content/DeepLigType/dataset/pdb.molcache
